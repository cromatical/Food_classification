# %%
import os
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from matplotlib.image import imread

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Input, GlobalAveragePooling2D, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
config = {
    'BATCH_SIZE':32,
    'IMAGE_SIZE': (240, 240),
    'SEED':42,
    'LEARNING_RATE':0.003,
    'EPOCHS':15
}

# %%
data_dir = '/content/drive/MyDrive/Doing_lab/food-data'

# apply augmentation 
train_image_gen = ImageDataGenerator(validation_split=0.2,
                               rotation_range=20,
                               width_shift_range=0.2,
                               height_shift_range=0.2,
                               zoom_range=0.2,
                               horizontal_flip=True,
                               vertical_flip=True,
                               fill_mode='nearest')
                            
validation_image_gen = ImageDataGenerator(validation_split=0.2)

train_generator = train_image_gen.flow_from_directory(
    data_dir,
    shuffle=True,
    seed=config['SEED'],
    target_size=config['IMAGE_SIZE'],
    batch_size=config['BATCH_SIZE'],
    class_mode='sparse',
    subset='training')

validation_generator = validation_image_gen.flow_from_directory(
    data_dir, 
    shuffle=False,
    seed=config['SEED'],
    target_size=config['IMAGE_SIZE'],
    batch_size=config['BATCH_SIZE'],
    class_mode='sparse',
    subset='validation')
# Out:
# Found 4419 images belonging to 55 classes.
# Found 1103 images belonging to 55 classes.

# %%
from tensorflow.keras.applications import EfficientNetB1

# 클래스 개수
num_classes = train_generator.num_classes

# 모델 생성 함수
# 사전학습 모델을 불러와 마지막 레이어를 제외하고 전부 frozen

def create_model(input_shape, num_classes):
  base_model = EfficientNetB1(include_top=False, weights='imagenet')
  base_model.trainable = False
  
  inputs = Input(shape=input_shape)
  x = base_model(inputs, training=False)

  x = GlobalAveragePooling2D()(x)
  outputs = Dense(num_classes, activation='softmax')(x)

  model = Model(inputs, outputs)
  opt = Adam(learning_rate=config['LEARNING_RATE'])

  model.compile(
      optimizer=opt,
      loss='sparse_categorical_crossentropy',
      metrics=['accuracy']
  )
  return model

model = create_model(config['IMAGE_SIZE'] + (3,), num_classes)
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb1_notop.h5
# 27025408/27018416 [==============================] - 1s 0us/step
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 240, 240, 3)]     0
# _________________________________________________________________
# efficientnetb1 (Functional)  (None, None, None, 1280)  6575239
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1280)              0
# _________________________________________________________________
# dense (Dense)                (None, 55)                70455
# =================================================================
# Total params: 6,645,694
# Trainable params: 70,455
# Non-trainable params: 6,575,239
# _________________________________________________________________

# %%
checkpoint_path = '/content/drive/MyDrive/Doing_lab/checkpoint/CASE3_EfficientNetB1.h5'

mc = ModelCheckpoint(filepath=checkpoint_path,
                     save_weight_only=True,
                     save_best_only=True,
                     monitor='val_loss',
                     verbose=1)

es = EarlyStopping(monitor='val_loss',
                   patience=10,
                   verbose=1)

hist = model.fit(train_generator,
                 validation_data=validation_generator,
                 epochs=config['EPOCHS'],
                 callbacks=[mc, es])
# Out:
# Epoch 1/15
# 139/139 [==============================] - 2645s 19s/step - loss: 2.9163 - accuracy: 0.2885 - val_loss: 1.4302 - val_accuracy: 0.6065
#
# Epoch 00001: val_loss improved from inf to 1.43016, saving model to /content/drive/MyDrive/Doing_lab/checkpoint/CASE3_EfficientNetB1.h5
# Epoch 2/15
# 139/139 [==============================] - 101s 726ms/step - loss: 1.3005 - accuracy: 0.6496 - val_loss: 1.3158 - val_accuracy: 0.6374
#
# Epoch 00002: val_loss improved from 1.43016 to 1.31576, saving model to /content/drive/MyDrive/Doing_lab/checkpoint/CASE3_EfficientNetB1.h5
# Epoch 3/15
# 139/139 [==============================] - 102s 734ms/step - loss: 1.0079 - accuracy: 0.7315 - val_loss: 1.2551 - val_accuracy: 0.6528
#
# Epoch 00003: val_loss improved from 1.31576 to 1.25510, saving model to /content/drive/MyDrive/Doing_lab/checkpoint/CASE3_EfficientNetB1.h5
# Epoch 4/15
# 139/139 [==============================] - 102s 735ms/step - loss: 0.8369 - accuracy: 0.7714 - val_loss: 1.2514 - val_accuracy: 0.6573
#
# Epoch 00004: val_loss improved from 1.25510 to 1.25145, saving model to /content/drive/MyDrive/Doing_lab/checkpoint/CASE3_EfficientNetB1.h5
# Epoch 5/15
# 139/139 [==============================] - 102s 731ms/step - loss: 0.7595 - accuracy: 0.7911 - val_loss: 1.2270 - val_accuracy: 0.6700
#
# Epoch 00005: val_loss improved from 1.25145 to 1.22700, saving model to /content/drive/MyDrive/Doing_lab/checkpoint/CASE3_EfficientNetB1.h5
# Epoch 6/15
# 139/139 [==============================] - 101s 725ms/step - loss: 0.6401 - accuracy: 0.8305 - val_loss: 1.2285 - val_accuracy: 0.6691
#
# Epoch 00006: val_loss did not improve from 1.22700
# Epoch 7/15
# 139/139 [==============================] - 102s 734ms/step - loss: 0.5984 - accuracy: 0.8356 - val_loss: 1.2231 - val_accuracy: 0.6700
#
# Epoch 00007: val_loss improved from 1.22700 to 1.22308, saving model to /content/drive/MyDrive/Doing_lab/checkpoint/CASE3_EfficientNetB1.h5
# Epoch 8/15
# 139/139 [==============================] - 101s 726ms/step - loss: 0.5040 - accuracy: 0.8597 - val_loss: 1.2185 - val_accuracy: 0.6564
#
# Epoch 00008: val_loss improved from 1.22308 to 1.21846, saving model to /content/drive/MyDrive/Doing_lab/checkpoint/CASE3_EfficientNetB1.h5
# Epoch 9/15
# 139/139 [==============================] - 101s 727ms/step - loss: 0.4534 - accuracy: 0.8769 - val_loss: 1.2493 - val_accuracy: 0.6618
#
# Epoch 00009: val_loss did not improve from 1.21846
# Epoch 10/15
# 139/139 [==============================] - 102s 731ms/step - loss: 0.4244 - accuracy: 0.8837 - val_loss: 1.2762 - val_accuracy: 0.6646
#
# Epoch 00010: val_loss did not improve from 1.21846
# Epoch 11/15
# 139/139 [==============================] - 101s 723ms/step - loss: 0.4037 - accuracy: 0.8896 - val_loss: 1.2627 - val_accuracy: 0.6618
#
# Epoch 00011: val_loss did not improve from 1.21846
# Epoch 12/15
# 139/139 [==============================] - 100s 721ms/step - loss: 0.3742 - accuracy: 0.8984 - val_loss: 1.2735 - val_accuracy: 0.6673
#
# Epoch 00012: val_loss did not improve from 1.21846
# Epoch 13/15
# 139/139 [==============================] - 100s 716ms/step - loss: 0.3535 - accuracy: 0.9070 - val_loss: 1.2763 - val_accuracy: 0.6664
#
# Epoch 00013: val_loss did not improve from 1.21846
# Epoch 14/15
# 139/139 [==============================] - 101s 729ms/step - loss: 0.3524 - accuracy: 0.9090 - val_loss: 1.2728 - val_accuracy: 0.6700
#
# Epoch 00014: val_loss did not improve from 1.21846
# Epoch 15/15
# 139/139 [==============================] - 102s 732ms/step - loss: 0.3117 - accuracy: 0.9190 - val_loss: 1.2954 - val_accuracy: 0.6646
#
# Epoch 00015: val_loss did not improve from 1.21846

# %%
new_dict = dict([(value, key) for key, value in train_generator.class_indices.items()])
new_dict
# Out:
# {0: 'apple_pie',
#  1: 'baby_back_ribs',
#  2: 'baklava',
#  3: 'beef_carpaccio',
#  4: 'beef_tartare',
#  5: 'beet_salad',
#  6: 'beignets',
#  7: 'bibimbap',
#  8: 'bread_pudding',
#  9: 'breakfast_burrito',
#  10: 'bruschetta',
#  11: 'caesar_salad',
#  12: 'cannoli',
#  13: 'caprese_salad',
#  14: 'carrot_cake',
#  15: 'ceviche',
#  16: 'cheese_plate',
#  17: 'cheesecake',
#  18: 'chicken_curry',
#  19: 'chicken_quesadilla',
#  20: 'chicken_wings',
#  21: 'chocolate_cake',
#  22: 'chocolate_mousse',
#  23: 'churros',
#  24: 'clam_chowder',
#  25: 'club_sandwich',
#  26: 'crab_cakes',
#  27: 'creme_brulee',
#  28: 'croque_madame',
#  29: 'cup_cakes',
#  30: 'deviled_eggs',
#  31: 'donuts',
#  32: 'dumplings',
#  33: 'edamame',
#  34: 'eggs_benedict',
#  35: 'escargots',
#  36: 'falafel',
#  37: 'filet_mignon',
#  38: 'fish_and_chips',
#  39: 'fish_shaped_bun',
#  40: 'foie_gras',
#  41: 'french_fries',
#  42: 'french_onion_soup',
#  43: 'french_toast',
#  44: 'fried_calamari',
#  45: 'fried_rice',
#  46: 'frozen_yogurt',
#  47: 'garlic_bread',
#  48: 'gnocchi',
#  49: 'greek_salad',
#  50: 'grilled_cheese_sandwich',
#  51: 'hotteok',
#  52: 'kimbab',
#  53: 'sundae',
#  54: 'tteokbokki'}

# %%
# 그래프
fig, ax = plt.subplots(2, 1, figsize=(12, 10))

# loss, val_loss
ax[0].set_ylabel("loss")
ax[0].set_xlabel("Epoch")
ax[0].plot(hist.history['loss'], 'b-', label = 'loss')
ax[0].plot(hist.history['val_loss'], 'r-', label = 'val_loss')
ax[0].legend()

# acc, val_acc
ax[1].set_ylabel("Acc")
ax[1].set_xlabel("Epoch")
ax[1].plot(hist.history['accuracy'], 'b-', label = 'acc')
ax[1].plot(hist.history['val_accuracy'], 'r-', label = 'val_acc')
ax[1].legend()

plt.show()

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

validation_generator.reset()

# 예측값 
Y_pred = model.predict(validation_generator)
y_pred = np.argmax(Y_pred, axis=-1)

# 실제값
class_names = [key for key, value in train_generator.class_indices.items()]
y_real = validation_generator.classes[validation_generator.index_array]

# # confusion matrix
cm = confusion_matrix(y_real, y_pred)

# accuracy_score, recall_score, precision_score
print(classification_report(y_real, y_pred, target_names=class_names))

print("Acc :", accuracy_score(y_real, y_pred))
print("Recall :", recall_score(y_real, y_pred, average='macro'))
print("Precision :", precision_score(y_real, y_pred, average='macro'))
# Out:
#                          precision    recall  f1-score   support
#
#               apple_pie       0.47      0.35      0.40        20
#          baby_back_ribs       0.57      0.60      0.59        20
#                 baklava       0.71      0.50      0.59        20
#          beef_carpaccio       0.78      0.35      0.48        20
#            beef_tartare       0.55      0.55      0.55        20
#              beet_salad       0.54      0.35      0.42        20
#                beignets       0.77      0.50      0.61        20
#                bibimbap       0.93      0.65      0.76        20
#           bread_pudding       0.28      0.35      0.31        20
#       breakfast_burrito       0.69      0.90      0.78        20
#              bruschetta       0.42      0.65      0.51        20
#            caesar_salad       0.78      0.90      0.84        20
#                 cannoli       0.71      0.75      0.73        20
#           caprese_salad       0.60      0.60      0.60        20
#             carrot_cake       0.56      0.50      0.53        20
#                 ceviche       0.40      0.40      0.40        20
#            cheese_plate       0.86      0.60      0.71        20
#              cheesecake       0.45      0.65      0.53        20
#           chicken_curry       0.61      0.70      0.65        20
#      chicken_quesadilla       0.69      0.90      0.78        20
#           chicken_wings       0.67      0.70      0.68        20
#          chocolate_cake       0.67      0.70      0.68        20
#        chocolate_mousse       0.62      0.25      0.36        20
#                 churros       0.90      0.90      0.90        20
#            clam_chowder       0.86      0.95      0.90        20
#           club_sandwich       0.71      0.75      0.73        20
#              crab_cakes       0.36      0.60      0.45        20
#            creme_brulee       0.75      0.75      0.75        20
#           croque_madame       0.72      0.65      0.68        20
#               cup_cakes       0.83      0.75      0.79        20
#            deviled_eggs       0.57      0.60      0.59        20
#                  donuts       0.55      0.80      0.65        20
#               dumplings       0.86      0.95      0.90        20
#                 edamame       1.00      1.00      1.00        20
#           eggs_benedict       0.55      0.55      0.55        20
#               escargots       0.80      0.40      0.53        20
#                 falafel       0.68      0.65      0.67        20
#            filet_mignon       0.71      0.50      0.59        20
#          fish_and_chips       0.63      0.60      0.62        20
#         fish_shaped_bun       1.00      0.89      0.94        18
#               foie_gras       0.26      0.35      0.30        20
#            french_fries       0.86      0.90      0.88        20
#       french_onion_soup       0.73      0.80      0.76        20
#            french_toast       0.33      0.40      0.36        20
#          fried_calamari       0.79      0.75      0.77        20
#              fried_rice       0.73      0.80      0.76        20
#           frozen_yogurt       0.84      0.80      0.82        20
#            garlic_bread       0.61      0.70      0.65        20
#                 gnocchi       0.70      0.80      0.74        20
#             greek_salad       0.64      0.70      0.67        20
# grilled_cheese_sandwich       0.46      0.30      0.36        20
#                 hotteok       0.95      0.95      0.95        20
#                  kimbab       1.00      0.92      0.96        24
#                  sundae       0.88      0.83      0.86        18
#              tteokbokki       0.86      0.83      0.84        23
#
#                accuracy                           0.66      1103
#               macro avg       0.68      0.66      0.66      1103
#            weighted avg       0.68      0.66      0.66      1103
#
# Acc : 0.6645512239347234
# Recall : 0.6639086517347388
# Precision : 0.6813339581543845

# %%
import itertools

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
plt.figure(figsize=(20,20))
plot_confusion_matrix(cm, classes=class_names, title='Confusion matrix, without normalization')
# Out:
# Confusion matrix, without normalization
# [[ 7  0  0 ...  0  0  0]
#  [ 0 12  0 ...  0  0  0]
#  [ 1  0 10 ...  0  0  0]
#  ...
#  [ 0  0  0 ... 22  1  0]
#  [ 0  0  0 ...  0 15  1]
#  [ 0  0  0 ...  0  0 19]]
